# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridjutsabit85/KKA-X-Semester-1/blob/main/3_Aplikasi_sederhana_Ridju_Ahmad_NajmiT_X_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang=int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar=int(input("Masukkan lebar dari persegi panjang (cm): "))

luas_persegi_panjang=panjang * lebar

print (f"Luas Persegi panjang yaitu{luas_persegi_panjang}cm^2.")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar dari persegi panjang (cm): 4
# Luas Persegi panjang yaitu20cm^2.

# %% [markdown]
# #Aplikasi menghitung volume balok

# %%
panjang = int(input("masukkan panjang dari balok (cm): "))
lebar = int(input(" masukkan lebar dari balok (cm) "))
tinggi = int(input(" masukan tinggi dari balok (cm): "))

volume_balok = panjang*lebar*tinggi

print(f"volume balok yaitu {volume_balok} cm^3.")
# Out:
# masukkan panjang dari balok (cm): 5
#  masukkan lebar dari balok (cm) 4
#  masukan tinggi dari balok (cm): 3
# volume balok yaitu 60 cm^3.
